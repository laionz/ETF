# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from plotnine import *
import seaborn as sns

# %% [markdown]
# We will do an analysis based on a dataset of ETF built by scrapping the ishares.com web

# %%
df= pd.read_csv("etfs_equity.csv")

# %%
pd.set_option('display.max_columns', 50)

# %%
df.head()
# Out:
#     Unnamed: 0    assetClass  beta3Yr    cost                        date  \
# 0            0        Equity     1.18  0.0030  2019-06-17 00:00:00.000000
# 1            1   Real Estate     0.34  0.0048  2019-06-17 00:00:00.000000
# 2            2        Equity      NaN  0.0018  2019-06-17 00:00:00.000000
# 3            3        Equity     0.55  0.0031  2019-06-17 00:00:00.000000
# 4            4        Equity     1.06  0.0015  2019-06-17 00:00:00.000000
# 5            5        Equity     0.56  0.0047  2019-06-17 00:00:00.000000
# 6            6        Equity      NaN  0.0047  2019-06-17 00:00:00.000000
# 7            7        Equity      NaN  0.0015  2019-06-17 00:00:00.000000
# 8            8  Fixed Income     0.09  0.0006  2019-06-17 00:00:00.000000
# 9            9        Equity     0.61  0.0047  2019-06-17 00:00:00.000000
# 10          10  Fixed Income    -0.13  0.0015  2019-06-17 00:00:00.000000
# 11          11        Equity     0.69  0.0069  2019-06-17 00:00:00.000000
# ...

# %%
df.corr()
# Out:
#                       Unnamed: 0   beta3Yr      cost  distYield  modelOad  \
# Unnamed: 0              1.000000 -0.076054  0.148059   0.011990 -0.233077
# beta3Yr                -0.076054  1.000000  0.257171  -0.132977 -0.273326
# cost                    0.148059  0.257171  1.000000   0.020806 -0.195065
# distYield               0.011990 -0.132977  0.020806   1.000000  0.079135
# modelOad               -0.233077 -0.273326 -0.195065   0.079135  1.000000
# numHoldings             0.008731 -0.243950 -0.355627   0.021848  0.133606
# optionAdjustedSpread    0.122022  0.939339  0.694876   0.957820  0.013248
# priceBook              -0.143841  0.287994 -0.220368  -0.201605       NaN
# priceEarnings          -0.103235  0.051446 -0.262253  -0.236756       NaN
# sharesOutstanding       0.076975 -0.072260 -0.169932   0.007016  0.010005
# standardDeviation3Yr    0.077864  0.697044  0.418328  -0.110980  0.740355
# thirtyDaySecYield       0.059710 -0.333979  0.077516   0.388541 -0.032860
# ...

# %%
df.assetClass.unique()
# Out:
# array(['Equity', 'Real Estate', 'Fixed Income', 'Multi Asset', nan,
#        'Commodity'], dtype=object)

# %% [markdown]
# We will reduce the analysis to ETF of fixed income and variable income only

# %%
eliminate= df[(df["assetClass"]!='Equity') & (df["assetClass"]!='Fixed Income') ].index

# %%
name
# Out:
# Int64Index([  1,  16,  34,  50,  58,  63,  64,  75,  80,  88, 103, 118, 126,
#             132, 144, 174, 212, 217, 224, 229, 230, 237, 285, 286, 287],
#            dtype='int64')

# %%
df.drop(eliminate , inplace=True)

# %%
df.assetClass.unique()

# %%
df.assetClass.value_counts()

# %%
sns.pairplot(df, kind ="reg")

# %%
df= df.fillna(0)

# %%
sns.pairplot(df)

# %%
df.columns

# %%
sns.pairplot(df[['beta3Yr', 'cost','distYield', 'modelOad', 'numHoldings', 'optionAdjustedSpread',
       'priceBook', 'priceEarnings', 'sharesOutstanding',
       'standardDeviation3Yr', 'thirtyDaySecYield', 'totalNetAssets',
       'twelveMonTrlYld', 'weightedAvgCoupon', 'weightedAvgLife',
       'yieldToWorst' ]], kind="reg")

# %%
p = ggplot(aes(x= 'beta3Yr', y='thirtyDaySecYield'), df)+ geom_point()

# %%
print(p)

# %%
variables = list(df.columns)[4:]
mdf = pd.melt(df, id_vars='ticker')

# %%
mdf

# %%
corrmat = df.corr()
f, ax = plt.subplots()
sns.heatmap(corrmat, square=True);

# %%
#los mas correlacionados, zoom heatmap
k = 5 #number of variables for heatmap
cols = corrmat.nlargest(k, 'twelveMonTrlYld')['twelveMonTrlYld'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
cols = corrmat.nlargest(k, 'twelveMonTrlYld')['twelveMonTrlYld'].index
print(cols.values)
